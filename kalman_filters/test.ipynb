# %%
import numpy as np
import matplotlib.pyplot as plt
from toy_data_generation import gen_toy_example
from KalmanFilter import KalmanFilter

# %%
N = 50
K = 50

params_path = None
verbose = True

a_0 = np.zeros((N,1))
A, Y = gen_toy_example(a_0, N, K)
kalman_filter = KalmanFilter(params_path=params_path, verbose=verbose)

# %%
lmbda = 1
kalman_filter.fit(A, Y, lmbda)
# Out:
# F : [[0.48743663]]
# F.shape : (1, 1)
# Q : 1.1450037625644982
# Q.shape : ()
# G : [[0.54228087]]
# G.shape (1, 1)
# R : 1.0094840714975377
# R.shape : ()

# %%
state_num = np.arange(K)
plt.figure()
plt.scatter(state_num, obs[1], marker = '*', color='red', label='observations')
plt.plot(state_num, h_states[1], color= 'blue', label='true states')

plt.xlabel('time')
plt.ylabel('state')

plt.legend()
plt.show()

# %%
print(PAP)
# Out:
# [[8. 8.]
#  [8. 8.]]

# %%
P@P@P
# Out:
# array([[4., 4.],
#        [4., 4.]])
